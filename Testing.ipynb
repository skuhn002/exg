# %%
from EggPy import session

# %%
S1 = session('OpenBCI-RAW-20Hz-visual-stimulus-in-first-30-sec.txt')

# %%
S1.get_data()

# %%
S1.crop_data(after=30)
# Out:
# Removed data after 30 seconds.

# %%
S1.data_chns
# Out:
#         Time  eeg_channel_1  eeg_channel_2  eeg_channel_3  eeg_channel_4  \
# 0      0.000  -1.820205e+06   -4500000.375  -2.418983e+06   -4500000.375
# 1      0.008  -1.822476e+06   -4500000.375  -2.421965e+06   -4500000.375
# 2      0.016  -1.821078e+06   -4500000.375  -2.419140e+06   -4500000.375
# 3      0.024  -1.822373e+06   -4500000.375  -2.422613e+06   -4500000.375
# 4      0.032  -1.822149e+06   -4500000.375  -2.419156e+06   -4500000.375
# ...      ...            ...            ...            ...            ...
# 3746  29.968  -1.828224e+06   -4500000.375  -2.358792e+06   -4500000.375
# 3747  29.976  -1.829635e+06   -4500000.375  -2.362063e+06   -4500000.375
# 3748  29.984  -1.829551e+06   -4500000.375  -2.359036e+06   -4500000.375
# 3749  29.992  -1.828711e+06   -4500000.375  -2.362133e+06   -4500000.375
# 3750  30.000  -1.829890e+06   -4500000.375  -2.358562e+06   -4500000.375
#
#       eeg_channel_5  eeg_channel_6  eeg_channel_7  eeg_channel_8  \
# ...

# %%
S1.preprocess(hpf=5, lpf=50, rmv_avg=True)
# Out:
#         Time  eeg_channel_1  eeg_channel_2  eeg_channel_3  eeg_channel_4  \
# 0      0.000            NaN            NaN            NaN            NaN
# 1      0.008            NaN            NaN            NaN            NaN
# 2      0.016            NaN            NaN            NaN            NaN
# 3      0.024            NaN            NaN            NaN            NaN
# 4      0.032            NaN            NaN            NaN            NaN
# ...      ...            ...            ...            ...            ...
# 3746  29.968            NaN            NaN            NaN            NaN
# 3747  29.976            NaN            NaN            NaN            NaN
# 3748  29.984            NaN            NaN            NaN            NaN
# 3749  29.992            NaN            NaN            NaN            NaN
# 3750  30.000            NaN            NaN            NaN            NaN
#
#       eeg_channel_5  eeg_channel_6  eeg_channel_7  eeg_channel_8  \
# ...

# %%
S1.make_fft()

# %%
S1.plot(ver='fq', chns=[1,3,6,8])
# Out:
# <div>                            <div id="d5fe8eb8-92b6-409f-b0a7-843b773b3ef8" class="plotly-graph-div" style="height:1200px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5fe8eb8-92b6-409f-b0a7-843b773b3ef8")) {                    Plotly.newPlot(                        "d5fe8eb8-92b6-409f-b0a7-843b773b3ef8",                        [{"mode":"lines","name":"EEG Ch.1","type":"scatter","x":[0.0,0.06103515625,0.1220703125,0.18310546875,0.244140625,0.30517578125,0.3662109375,0.42724609375,0.48828125,0.54931640625,0.6103515625,0.67138671875,0.732421875,0.79345703125,0.8544921875,0.91552734375,0.9765625,1.03759765625,1.0986328125,1.15966796875,1.220703125,1.28173828125,1.3427734375,1.40380859375,1.46484375,1.52587890625,1.5869140625,1.64794921875,1.708984375,1.77001953125,1.8310546875,1.892089843
# ...
